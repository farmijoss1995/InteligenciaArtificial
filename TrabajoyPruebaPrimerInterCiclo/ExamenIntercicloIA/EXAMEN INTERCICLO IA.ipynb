# %%
from neomodel import (config, StructuredNode, StringProperty, IntegerProperty,
    UniqueIdProperty, RelationshipTo, RelationshipFrom)
from neomodel import db
import tweepy
import json

# %%
config.DATABASE_URL = 'bolt://neo4j:12345@localhost:7687'
config.ENCRYPTED_CONNECTION = False

# %%
#Autenticacion
consumer_key="BcTSXI2FFPfT0LA5Ok9vLDNwE"
consumer_secret="mpf2CtC3XH5JsSXT9iXpeeQVktco4Kd3ZQpfwjx3d4V21BPJjH"
access_token="1399742841249751041-788K9sdI5RWfVWCpVCMlg39HE2bCCn"
access_token_secret="DQcqXuswo6TkHSHgjttmn4LIoNC98Smn3kcPXlokxd0zX"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token,access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
class Alcalde(StructuredNode):
    nombre = StringProperty(unique_index=True)

class Tweets(StructuredNode):
    id_Tts = UniqueIdProperty()
    Noticias = StringProperty(unique_index=False)
    Date = StringProperty(unique_index=False)
    Retweets = StringProperty(unique_index=False)
    usuario = RelationshipTo('Usuario', 'tweetUsuario')
    alcalde = RelationshipTo('Alcalde', 'tweetAlcalde')
    
class Usuario(StructuredNode):
    idUsuario = UniqueIdProperty()
    nombre = StringProperty(unique_index=True)
    tweet = RelationshipFrom('Tweets','tweetUsuario')

# %%
alcalde_raiz = Alcalde(nombre="Delfín Quishpe").save()

id_Twt = "" 
new = ""
name_user = ""
date = ""
copy = ""
id_user = ""

for tweet in tweepy.Cursor(api.search, q="Delfín Quishpe", tweet_mode= "extended").items(299):
    for user in tweet.entities["user_mentions"]:
        
        id_Twt =  tweet.id
        news = tweet.full_text
        name_user = user["name"]
        id_user = user["id_str"]
        date = tweet.created_at
        copy = tweet.retweet_count
        print ("Registro: ")
        print ("Id:",id_Twt)
        print ("Noticias:",news)
        print ("Usuario:", name_user)
        print ("Fecha:",date)
        print ("Retweets:",copy)
        print ("IdUsuario", id_user)
        print ("\n")
       
        tw = Tweets(id_TTS=id_Twt, Noticias=news, Date=date, Retweets=copy).save()
        us = Usuario(idUsuario=id_user,nombre=name_user).save()
        #Relaciones
        tw.usuario.connect(us)
        tw.alcalde.connect(alcalde_raiz)
# Out:
# Registro:
# Id: 1399839211591774209
# Noticias: RT @teleamazonasec: Quishpe podría ser sentenciado a una pena de 3 a 5 años de prisión https://t.co/4hWlylERW3 https://t.co/fTSrgoGc90
# Usuario: Teleamazonas
# Fecha: 2021-06-01 21:24:10
# Retweets: 87
# IdUsuario 95217117
#
#
# Registro:
# Id: 1399837004263723009
# Noticias: RT @teleamazonasec: Quishpe podría ser sentenciado a una pena de 3 a 5 años de prisión https://t.co/4hWlylERW3 https://t.co/fTSrgoGc90
# Usuario: Teleamazonas
# Fecha: 2021-06-01 21:15:24
# Retweets: 87
# IdUsuario 95217117
#
#
# Registro:
# Id: 1399836311834578946
# Noticias: RT @teleamazonasec: Quishpe podría ser sentenciado a una pena de 3 a 5 años de prisión https://t.co/4hWlylERW3 https://t.co/fTSrgoGc90
# Usuario: Teleamazonas
# Fecha: 2021-06-01 21:12:39
# Retweets: 87
# IdUsuario 95217117
#
#
# Registro:
# Id: 1399836263558045704
# ...
